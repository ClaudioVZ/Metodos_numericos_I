# %% [markdown]
# # Contenido
#
# * Raíces de ecuaciones de una variable
#     * Métodos cerrados
#         * [Método de la bisección](01_Raices_de_ecuaciones_de_una_variable/01_Biseccion.ipynb)
#         * [Método de la falsa posición](01_Raices_de_ecuaciones_de_una_variable/02_Falsa_posicion.ipynb)
#         * [Método de la falsa posición modificada](01_Raices_de_ecuaciones_de_una_variable/03_Falsa_posicion_modificada.ipynb)
#     * Métodos abiertos
#         * [Método del punto fijo](01_Raices_de_ecuaciones_de_una_variable/04_Punto_fijo.ipynb)
#         * [Método de Newton-Raphson](01_Raices_de_ecuaciones_de_una_variable/05_Newton-Raphson.ipynb)
#         * [Método de la secante](01_Raices_de_ecuaciones_de_una_variable/06_Secante.ipynb)
#         * [Método de la secante modificada](01_Raices_de_ecuaciones_de_una_variable/07_Secante_modificada.ipynb)
# * Sistemas de ecuaciones lineales
#     * [Operaciones con matrices](02_Sistema_de_ecuaciones_lineales/01_Operaciones_con_matrices.ipynb)
#     * Métodos directos
#         * [Eliminación de Gauss](02_Sistema_de_ecuaciones_lineales/02_Eliminacion_Gauss.ipynb)
#         * [Eliminación hacia adelante revisitado](02_Sistema_de_ecuaciones_lineales/03_Eliminacion_adelante_revisitado.ipynb)
#         * [Eliminación de Gauss](02_Sistema_de_ecuaciones_lineales/04_Eliminacion_Gauss.ipynb)
#         * [Eliminación hacia atrás revisitado](02_Sistema_de_ecuaciones_lineales/05_Eliminacion_atras_revisitado.ipynb)
#         * [Factorización LU](02_Sistema_de_ecuaciones_lineales/06_Factorizacion_LU.ipynb)
#             * [Algoritmo de Doolittle](02_Sistema_de_ecuaciones_lineales/07_LU_Doolittle.ipynb)
#             * [Algoritmo de Crout](02_Sistema_de_ecuaciones_lineales/08_LU_Crout.ipynb)
#         * [Algoritmo de Doolittle revisitado](02_Sistema_de_ecuaciones_lineales/09_LU_Doolittle_revisitado.ipynb)
#         * [Algoritmo de Crout revisitado](02_Sistema_de_ecuaciones_lineales/10_LU_Crout_revisitado.ipynb)
#         * [Factorización de Cholesky](02_Sistema_de_ecuaciones_lineales/11_Factorizacion_Cholesky.ipynb)
#             * [Algoritmo de Cholesky-Banachiewicz](02_Sistema_de_ecuaciones_lineales/12_Cholesky_Banachiewicz.ipynb)
#             * [Algoritmo de Cholesky-Crout](02_Sistema_de_ecuaciones_lineales/13_Cholesky_Crout.ipynb)
#     * Métodos iterativos
#         * [Método de Gauss-Jacobi](02_Sistema_de_ecuaciones_lineales/14_Metodo_Gauss-Jacobi.ipynb)
#         * [Método de Gauss-Seidel](02_Sistema_de_ecuaciones_lineales/15_Metodo_Gauss-Seidel.ipynb)
#         * [Métodos de relajación](02_Sistema_de_ecuaciones_lineales/16_Metodos_relajacion.ipynb)
#             * [Método de Gauss-Jacobi ponderado](02_Sistema_de_ecuaciones_lineales/17_Metodo_Gauss-Jacobi_ponderado.ipynb)
#             * [Método SOR](02_Sistema_de_ecuaciones_lineales/18_Metodo_SOR.ipynb)
# * Interpolación
#     * [Diferencias divididas de Newton](03_Interpolacion/01_Diferencias_Newton.ipynb)
# * Diferenciación
#     * Diferencias finitas
#         * Nodos desigualmente espaciados
#             * [Serie de Taylor]()
#             * [Polinomio de Lagrange](04_Diferenciacion/02_Polinomio_Lagrange.ipynb)
#             * [Método de los coeficientes indeterminados]()
#         * Nodos igualmente espaciados
#             * [Serie de Taylor](04_Diferenciacion/04_Serie_Taylor.ipynb)
#             * [Polinomio de Lagrange]()
#             * [Método de los coeficientes indeterminados](04_Diferenciacion/06_Coeficientes_indeterminados.ipynb)
#     * [Extrapolación de Richardson](04_Diferenciacion/07_Extrapolacion_Richardson.ipynb)
# * Integración
#     * Fórmulas cerradas de Newton-Cotes
#         * Nodos desigualmente espaciados
#             * Polinomio de Lagrange
#                 * [Regla del trapecio](05_Integracion/01_Trapecio.ipynb)
#                 * [Regla de Simpson 1/3](05_Integracion/02_Simpson_13.ipynb)
#                 * [Regla de Simpson 3/8](05_Integracion/03_Simpson_38.ipynb)
#                 * [Regla de Boole](05_Integracion/04_Boole.ipynb)
#             * [Método de los coeficientes indeterminados](05_Integracion/05_Coeficientes_indeterminados.ipynb)
#         * Nodos igualmente espaciados
#             * Polinomio de Lagrange
#                 * [Regla del trapecio](05_Integracion/06_Trapecio.ipynb)
#                 * [Regla de Simpson 1/3](05_Integracion/07_Simpson_13.ipynb)
#                 * [Regla de Simpson 3/8](05_Integracion/08_Simpson_38.ipynb)
#                 * [Regla de Boole](05_Integracion/09_Boole.ipynb)
#             * [Método de los coeficientes indeterminados](05_Integracion/10_Coeficientes_indeterminados.ipynb)
# * Valores propios
#     * [Método de Leverrier-Faddeev](06_Valores_y_vectores_propios/01_Leverrier-Faddeev.ipynb)
#     * [Método de Leverrier-Faddeev (algoritmo alterno)](06_Valores_y_vectores_propios/02_Leverrier-Faddeev.ipynb)
